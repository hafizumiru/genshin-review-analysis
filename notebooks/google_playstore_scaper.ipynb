# %%
from google_play_scraper import reviews, Sort
import pandas as pd
import time
from datetime import datetime

# %%
# Target aplikasi
package_name = 'com.miHoYo.GenshinImpact'

# Tentukan rentang tanggal review yang ingin diambil
start_date = datetime(2025, 1, 1)  # Tanggal mulai

end_date = datetime(2025, 2, 11)        # Gunakan Line ini jika tanggal yang diinginkan adalah custom
# end_date = datetime.today()         # Gunakan Line ini jika tanggal yang diinginkan adalah hari ini

version = '5.3'  # Versi dari aplikasi

# Penyimpanan review
all_reviews = []
next_token = None
BATCH_SIZE = 100

while True:
    print(f"Mengambil review ke-{len(all_reviews) + 1} sampai {len(all_reviews) + BATCH_SIZE}...")

    result, next_token = reviews(
        package_name,
        lang='id',
        country='id',
        sort=Sort.NEWEST,
        count=BATCH_SIZE,
        continuation_token=next_token
    )

    if not result:
        print("Tidak ada review lagi.")
        break

    for r in result:
        review_date = r['at']

        # Jika review lebih tua dari start_date, hentikan pengambilan
        if review_date < start_date:
            print("Mencapai batas tanggal awal, berhenti...")
            next_token = None
            break

        # Jika review ada di antara rentang tanggal yang diminta
        if start_date <= review_date <= end_date:
            all_reviews.append(r)

    if not next_token:
        break

    time.sleep(1)

# Konversi ke DataFrame
df = pd.DataFrame([{
    "ReviewID": r.get("reviewId"),
    "Username": r.get("userName"),
    "UserImage": r.get("userImage"),
    "Content": r.get("content"),
    "Score": r.get("score"),
    "ThumbsUpCount": r.get("thumbsUpCount"),
    "ReviewCreatedVersion": r.get("reviewCreatedVersion"),
    "at": r.get("at"),
    "ReplyContent": r.get("replyContent"),
    "RepliedAt": r.get("repliedAt"),
    "AppVersion": r.get("reviewCreatedVersion"),
} for r in all_reviews])

# Simpan ke CSV
output_path = f'../data/review_genshin_{version}.csv'
df.to_csv(output_path, index=False, encoding='utf-8-sig')

print(f"Selesai! {len(df)} review disimpan antara {start_date.strftime('%Y-%m-%d')} dan {end_date.strftime('%Y-%m-%d')}.")
# Out:
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-1 sampai 100...
# Mengambil review ke-63 sampai 162...
# Mengambil review ke-163 sampai 262...
# Mengambil review ke-263 sampai 362...
# Mengambil review ke-363 sampai 462...
# Mengambil review ke-463 sampai 562...
# Mengambil review ke-563 sampai 662...
# Mengambil review ke-663 sampai 762...
# Mengambil review ke-763 sampai 862...
# Mengambil review ke-863 sampai 962...
# Mengambil review ke-963 sampai 1062...
# Mengambil review ke-1063 sampai 1162...
# Mengambil review ke-1163 sampai 1262...
# Mengambil review ke-1263 sampai 1362...
# Mengambil review ke-1363 sampai 1462...
# Mengambil review ke-1463 sampai 1562...
# Mengambil review ke-1563 sampai 1662...
# Mengambil review ke-1663 sampai 1762...
# Mengambil review ke-1763 sampai 1862...
# Mengambil review ke-1863 sampai 1962...
# Mengambil review ke-1963 sampai 2062...
# Mengambil review ke-2063 sampai 2162...
# Mengambil review ke-2163 sampai 2262...
# Mengambil review ke-2263 sampai 2362...
# Mengambil review ke-2363 sampai 2462...
# Mengambil review ke-2463 sampai 2562...
# Mencapai batas tanggal awal, berhenti...
# Selesai! 2471 review disimpan antara 2025-01-01 dan 2025-02-11.
