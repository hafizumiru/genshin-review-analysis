# %%
# Library yang digunakan
import pandas as pd

# %% [markdown]
# ## 💡 Load Data

# %%
#Load Dataser
file_path = "../data/review_genshin_uncleaned.csv"
df = pd.read_csv(file_path)
# Out:
# C:\Users\mirur\AppData\Local\Temp\ipykernel_25876\2310862458.py:3: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
# Show Dataset
df.head(10)
# Out:
#                                reviewId         userName  \
# 0  044af800-8184-463d-915d-e9382c4cdde7  Pengguna Google
# 1  e8e32740-62b4-4755-ae8b-0d50c71d7e33  Pengguna Google
# 2  39853dd9-f562-4b6b-8621-7fa14465cfd3  Pengguna Google
# 3  380ae1d4-16f2-4db2-83bd-f14ba776f76f  Pengguna Google
# 4  3548cb24-2d7e-423f-98f3-f11586a27144  Pengguna Google
# 5  6d772cec-7d3f-4080-9296-164afd052765  Pengguna Google
# 6  4101f5f9-bdb9-41e4-b540-2f952d146c30  Pengguna Google
# 7  5a67f5c8-1014-4cb9-9a16-618386cf43a9  Pengguna Google
# 8  f13a6c81-621e-4b63-bb14-1a6da0040d2a  Pengguna Google
# 9  b0bc28bb-6f07-45ec-a81c-3a20d406ac26  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
# 5  https://play-lh.googleusercontent.com/EGemoI2N...
# 6  https://play-lh.googleusercontent.com/EGemoI2N...
# 7  https://play-lh.googleusercontent.com/EGemoI2N...
# 8  https://play-lh.googleusercontent.com/EGemoI2N...
# 9  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                                  👌      5              0
# 1  comeback menggunakan Infinix 50 hot pro plus d...      5              0
# 2  Game baik wkwk tapi jujur aza dari segi lore, ...      5              0
# 3  Testing di HP Helio g99 dan ternyata sangat la...      5              1
# 4      Benerin sistem preupdate di ps4 kacau banget!      5              2
# 5  ayolah mang hoyo, susah banget kalo gacha arte...      5              0
# 6  Grafiknya kurang hd padahal sudah disetingan t...      4              0
# 7                                      keren anjayyy      5              0
# 8                  sorry rumput tetangga lebih hijau      1              2
# 9                             MANA TOMBOL SKIPNYA???      3              0
#
#       reviewCreatedVersion                   at replyContent repliedAt  \
# 0  5.5.0_31400259_31451966  2025-04-06 12:38:51          NaN       NaN
# 1    1.5.0_2574575_2578841  2025-04-06 12:29:10          NaN       NaN
# 2  5.5.0_31400259_31451966  2025-04-06 12:14:41          NaN       NaN
# 3  5.5.0_31400259_31451966  2025-04-06 11:48:46          NaN       NaN
# 4  5.5.0_31400259_31451966  2025-04-06 11:35:44          NaN       NaN
# 5  5.5.0_31400259_31451966  2025-04-06 11:12:59          NaN       NaN
# 6  5.5.0_31400259_31451966  2025-04-06 11:12:41          NaN       NaN
# 7  5.5.0_31400259_31451966  2025-04-06 10:11:11          NaN       NaN
# 8    2.3.0_4786731_4861639  2025-04-06 09:59:11          NaN       NaN
# 9  5.5.0_31400259_31451966  2025-04-06 09:27:57          NaN       NaN
#
#                 appVersion
# 0  5.5.0_31400259_31451966
# 1    1.5.0_2574575_2578841
# 2  5.5.0_31400259_31451966
# 3  5.5.0_31400259_31451966
# 4  5.5.0_31400259_31451966
# 5  5.5.0_31400259_31451966
# 6  5.5.0_31400259_31451966
# 7  5.5.0_31400259_31451966
# 8    2.3.0_4786731_4861639
# 9  5.5.0_31400259_31451966

# %% [markdown]
# | Kolom                | Deskripsi                                 |
# |----------------------|--------------------------------------------|
# | `reviewId`           | ID unik untuk review                       |
# | `userName`           | Nama pengguna                              |
# | `userImage`          | URL foto profil pengguna                   |
# | `content`            | Isi review                                 |
# | `score`              | Nilai rating (1–5)                         |
# | `thumbsUpCount`      | Jumlah likes pada review                   |
# | `reviewCreatedVersion` | Versi aplikasi saat review dibuat        |
# | `at`                 | Tanggal review                             |
# | `replyContent`       | Balasan dari developer (jika ada)          |
# | `repliedAt`          | Tanggal balasan                            |
# | `appVersion`         | Versi aplikasi                             |

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216034 entries, 0 to 216033
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              216034 non-null  object
#  1   userName              216034 non-null  object
#  2   userImage             216034 non-null  object
#  3   content               216034 non-null  object
#  4   score                 216034 non-null  int64
#  5   thumbsUpCount         216034 non-null  int64
#  6   reviewCreatedVersion  139560 non-null  object
#  7   at                    216034 non-null  object
#  8   replyContent          14365 non-null   object
#  9   repliedAt             14365 non-null   object
#  10  appVersion            139560 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 18.1+ MB

# %% [markdown]
# ## 🗃️ Drop Kolom

# %%
df_cleaned = df.drop(
    columns=['userName', 'userImage', 'replyContent', 'repliedAt', 'reviewCreatedVersion'])

# %% [markdown]
# Kolom 'userName' dan 'userImage' di-drop karena tidak mengandung informasi tekstual yang relevan untuk analisis NLP — mereka hanya metadata pengguna.
# Kolom 'replyContent' dan 'repliedAt' juga tidak digunakan karena fokus analisis NLP berada pada konten utama, bukan pada balasan atau timestamp-nya.
# Kolom 'ReviewCreatedVersion' juga di-drop karena informasinya redundan — nilainya sama dengan kolom 'appVersion'.

# %% [markdown]
# ## 🔄 Ubah Tipe Data

# %%
df_cleaned['at'] = pd.to_datetime(df_cleaned['at'], errors='coerce')

# %%
df_cleaned.head()
# Out:
#                                reviewId  \
# 0  044af800-8184-463d-915d-e9382c4cdde7
# 1  e8e32740-62b4-4755-ae8b-0d50c71d7e33
# 2  39853dd9-f562-4b6b-8621-7fa14465cfd3
# 3  380ae1d4-16f2-4db2-83bd-f14ba776f76f
# 4  3548cb24-2d7e-423f-98f3-f11586a27144
#
#                                              content  score  thumbsUpCount  \
# 0                                                  👌      5              0
# 1  comeback menggunakan Infinix 50 hot pro plus d...      5              0
# 2  Game baik wkwk tapi jujur aza dari segi lore, ...      5              0
# 3  Testing di HP Helio g99 dan ternyata sangat la...      5              1
# 4      Benerin sistem preupdate di ps4 kacau banget!      5              2
#
#                    at               appVersion
# 0 2025-04-06 12:38:51  5.5.0_31400259_31451966
# 1 2025-04-06 12:29:10    1.5.0_2574575_2578841
# 2 2025-04-06 12:14:41  5.5.0_31400259_31451966
# 3 2025-04-06 11:48:46  5.5.0_31400259_31451966
# 4 2025-04-06 11:35:44  5.5.0_31400259_31451966

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216034 entries, 0 to 216033
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   reviewId       216034 non-null  object
#  1   content        216034 non-null  object
#  2   score          216034 non-null  int64
#  3   thumbsUpCount  216034 non-null  int64
#  4   at             216034 non-null  datetime64[ns]
#  5   appVersion     139560 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 9.9+ MB
